# %% [markdown]
# # 1. Загрузка и подготовка данных

# %% [markdown]
# Отзывы для обучения уже загружены скриптом в SQLite3 бд.

# %%
import pandas as pd
import numpy as np
import sqlite3
import html
# %matplotlib inline

# %%
conn = sqlite3.connect('reviews_395.db')
c = conn.cursor()

# %%
train_data = list(c.execute("SELECT * FROM reviews;"))
conn.close()

# %%
data_raw = pd.read_csv("./train_data.csv")

# %%
data_asessed_1 = pd.read_csv("./train_data_results_1.csv", header=None).drop(columns=[0]).rename(columns={1:"text", 2: "label"})
data_asessed_2 = pd.read_csv("./train_data_results_2.csv", header=None).drop(columns=[0]).rename(columns={1:"text", 2: "label"})

# %%
data_assessed = data_asessed_1.append(data_asessed_2)

# %%
data_raw.text[1] in data_assessed["text"].unique()
# Out:
# True

# %%
len(data_assessed)
# Out:
# 1591

# %%
uqs = data_assessed.text.unique()
data_raw["duplicate"] = data_raw["text"].apply(lambda x: x in uqs)

# %%
data_assessed.columns
# Out:
# Index(['text', 'label'], dtype='object')

# %%
data.drop(columns=["Unnamed: 0","duplicate"], inplace=True)

# %%
data = data_assessed.append(data_raw[data_raw.duplicate == False])

# %% [markdown]
# ## 1.1 Очистка.

# %% [markdown]
# В данные попало много лишних тегов и прочего мусора. Для начала я уберу его, а также нормализую пунктуацию.

# %%
def normalize_text(text):
    _t = html.unescape(text)
    _t = _t.replace("<p>"," ")
    _t = _t.replace("</p>", " ")
    _t = _t.replace("\n", " ")
    _t = _t.replace("\r", " ")
    _t = _t.replace("\t", " ")
    _t = _t.replace('"', "")
    return _t.strip()

# %%
def normalize_text_re(text):
    _t = text
    _t = _t.replace("   "," ")
    _t = _t.replace("  "," ")
    return _t

# %%
data["text"] = data["text"].apply(lambda x: normalize_text(x))
data["text"] = data["text"].apply(lambda x: normalize_text_re(x))

# %%
len(data["text"].unique())
# Out:
# 1584

# %%
data["text"].tail(30)
# Out:
# 418    Плюсы: Быстрый. Минусы: Очень часто срабатывае...
# 419    Плюсы: Дизайн, камера, автономность. . Минусы:...
# 420    Плюсы: Их много. Минусы: Нету. Впечатления: Су...
# 421    Плюсы: Камера огонь) все приложения играю на м...
# 422    Плюсы: Доступная цена, профессиональная камера...
# 423    Плюсы: Жирный плюс. Минусы: Нету. Впечатления:...
# 424    Плюсы: Камера, батарея. Минусы: беспроводная з...
# 425    Плюсы: Камера аккумулятор процессор экран удоб...
# 426    Плюсы: Слабых мест не обнаружил. Были до этого...
# 427    Плюсы: камера, экран, аккумулятор , функция бы...
# 428    Плюсы: Очень приятный шустрый смартфон. Минусы...
# 429    Плюсы: Камера делает потрясающие фотографии. Д...
# 430    Плюсы: Камера, быстродействие. Минусы: Заряда ...
# 431    Плюсы: Отличная камера, особенно ночной режим....
# 432    Плюсы: Одни плюсы. Минусы: Не обнаружил. Впеча...
# 433    Плюсы: Все отлично. Минусы: Аккумулятор можно ...
# 434    Плюсы: Камера . Минусы: Нет. Впечатления: Можн...
# 435    Плюсы: Всё . Минусы: Нет. Впечатления: Убийца ...
# 436    Плюсы: Отличные камера и батарея. Минусы: Не н...
# 437    Плюсы: Фотокамера, быстродействие. Минусы: В с...
# 438    Плюсы: Фото . Минусы: Плохо работает геолокаци...
# 439    Плюсы: Тел супер . Минусы: Все супер только не...
# 440    Плюсы: Главный плюс это процессор, очень мощны...
# 441    Плюсы: Отличный аппарат с отличным процессором...
# 442    Плюсы: Все плюс. Минусы: Нет. Впечатления: Отл...
# 443    Плюсы: Хороший экран, топовый процессор, прием...
# 444    Плюсы: Процессор,камера,звук в наушниках. Мину...
# 445    Плюсы: Ошибка в описании. Цена указана на 64ГБ...
# 446    Плюсы: 1. Snapdragon 845. Последнее обновление...
# 447    Плюсы: Спасибо большое за ответ на вопрос поче...
# Name: text, dtype: object

# %%
data.to_csv("./train_data2.csv")

# %% [markdown]
# ## 2. Векторизация

# %% [markdown]
# Я хочу воспользоваться библиотекой gensim, потому что я уже использовал их эмбеддинги, и они отлично показали себя в классификации, даже на плохо обработанном датасете.
#
# Чтобы потом удобно запаковать это в sklearn pipeline, я реализую свой класс по образу `TfIdfVectorizer` из `sklearn.feature_extraction`

# %%
import gensim
from gensim.utils import simple_preprocess
from gensim.models import doc2vec
from tqdm import tqdm
from sklearn.base import TransformerMixin, BaseEstimator
from sklearn.feature_extraction.text import _VectorizerMixin
import numpy as np

class VectorizerTransformer(_VectorizerMixin, BaseEstimator):
    def __init__(self):
        pass

    def fit(self, raw_documents, y=None):
        X = self.preprocess(raw_documents)
        # print("Creating model...")
        model = gensim.models.doc2vec.Doc2Vec(
            vector_size=60, 
            min_count=10,
            epochs=40
        )
        # print("Building vocab...")
        model.build_vocab(X)
        # print("Training doc2vec...")
        model.train(X, total_examples=model.corpus_count, epochs=model.epochs)
        self.model = model
        return self

    def transform(self, raw_documents):
        X = self.preprocess(raw_documents)
        # print("Iinferring vectors...")
        vectorized_texts = []
        for doc_id, _ in enumerate(tqdm(X, desc="Inferring vectors: ")):
            inferred_vector = self.model.infer_vector(X[doc_id].words)
            vectorized_texts.append(inferred_vector)

        return vectorized_texts

    def preprocess(self, raw_documents):
        # print("Tokenization...")
        processed_texts = []
        for idx, text in enumerate(tqdm(raw_documents, desc="Tokenization: ")):
            text = normalize_text(text)
            text = normalize_text_re(text)
            processed_texts.append(doc2vec.TaggedDocument(simple_preprocess(text), [idx]))
        return processed_texts


    def fit_transform(self, texts, y=None) -> np.ndarray:
        self.fit(texts)
        X = self.transform(texts)
        
        return np.array(X)

# %% [markdown]
# ## 3. Обучение модели

# %%
X = data["text"]
y = data.label.map({"pos": 1, "neg": 0})
# y = data.label

# %%
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import roc_auc_score, accuracy_score, make_scorer
from sklearn.model_selection import cross_val_score, cross_validate

_model = make_pipeline(VectorizerTransformer(), GradientBoostingClassifier())

# %%
cross_val_score(_model, X, y, n_jobs=6)
# Out:
# array([0.85266458, 0.83018868, 0.86477987, 0.8081761 , 0.84591195])

# %%
_model.fit(X, y)
# Out:
# Tokenization: 100%|██████████| 1591/1591 [00:00<00:00, 18641.09it/s]
# Tokenization: 100%|██████████| 1591/1591 [00:00<00:00, 19806.00it/s]
# Inferring vectors: 100%|██████████| 1591/1591 [00:02<00:00, 581.03it/s]
# Pipeline(steps=[('vectorizertransformer', VectorizerTransformer()),
#                 ('gradientboostingclassifier', GradientBoostingClassifier())])

# %% [markdown]
# В принципе, качество уже не такое гадкое, можно попробовать сделать сабмит.

# %% [markdown]
# ## 4. Улучшение модели

# %% [markdown]
# Улучшить модель можно несколькими путями:
# + 1. Улучшить препроцессинг текста
# + 2. Подобрать параметры модели векторизации
# + 3. Подобрать параметры классификатора
# + 4. Попробовать другие классификаторы
# + 5. Сбалансировать классы для обучения
#
# Я сделаю только п.3 и 5

# %%
from sklearn.model_selection import GridSearchCV, ParameterGrid
_acc = make_scorer(accuracy_score)
_roc = make_scorer(roc_auc_score)
param_grid = {
    "n_estimators":[100,200,500,1000],
    "criterion": ("friedman_mse", "mse", "mae"),
    "max_depth": [3,5,7]
}

# %%
# так как я не подбираю параметры для векторизатора, 
# я сразу обучу его на полной выборке, потому что именно в таком виде он пойдёт в прод
_vectorizer = VectorizerTransformer()
vecs = _vectorizer.fit_transform(X)
# Out:
# Tokenization: 100%|██████████| 10152/10152 [00:00<00:00, 18281.08it/s]
# Tokenization: 100%|██████████| 10152/10152 [00:00<00:00, 18681.84it/s]
# Inferring vectors: 100%|██████████| 10152/10152 [00:21<00:00, 481.01it/s]

# %%
vecs = _vectorizer.transform(X)
# Out:
# Tokenization: 100%|██████████| 10152/10152 [00:00<00:00, 18575.85it/s]
# Inferring vectors: 100%|██████████| 10152/10152 [00:21<00:00, 475.87it/s]

# %%
sum(y == 0)
# Out:
# 720

# %%
from imblearn.under_sampling import NearMiss
from imblearn.over_sampling import ADASYN
# vecs_us, y_us = NearMiss(version=1).fit_resample(vecs, y)
vecs_us, y_us = ADASYN(n_jobs=6).fit_resample(vecs, y)

# %%
gscv_ = GridSearchCV(
    estimator=GradientBoostingClassifier(n_iter_no_change=20),
    param_grid=param_grid, 
    scoring={"accuracy":_acc,"roc_auc": _roc}, 
    n_jobs=6, refit=False)
res = gscv_.fit(vecs_us, y_us)

# %%
pd.DataFrame(res.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.352534      0.155106         0.001471        0.000041
# 1        0.519085      0.253067         0.001598        0.000290
# 2        0.637028      0.299767         0.001446        0.000102
# 3        0.333132      0.101000         0.001404        0.000036
# 4        0.572629      0.093534         0.001654        0.000281
# 5        0.556648      0.096708         0.001512        0.000062
# 6        0.987797      0.576777         0.001629        0.000232
# 7        0.650693      0.215789         0.002683        0.002398
# 8        0.449203      0.089226         0.001475        0.000072
# 9        0.423066      0.083767         0.001484        0.000059
# 10       0.444265      0.217753         0.001473        0.000083
# 11       0.511770      0.224160         0.001448        0.000093
# 12       0.356265      0.065806         0.001977        0.000754
# 13       0.396001      0.138139         0.001730        0.000626
# 14       0.444551      0.165937         0.001435        0.000094
# 15       0.547098      0.242519         0.001417        0.000053
# 16       0.546499      0.204145         0.001500        0.000089
# 17       0.493376      0.107202         0.001468        0.000052
# 18       0.422334      0.132532         0.001431        0.000056
# 19       0.411261      0.204507         0.001406        0.000095
# 20       0.572757      0.194445         0.001493        0.000097
# 21       0.354605      0.209214         0.001456        0.000117
# 22       0.426307      0.058053         0.001447        0.000059
# 23       0.391657      0.145005         0.001407        0.000071
# 24       2.323383      0.749884         0.001916        0.000828
# 25       2.292552      1.016482         0.002064        0.001473
# 26       3.711508      3.894868         0.002366        0.001347
# 27       3.217452      0.773571         0.001380        0.000046
# 28       1.386932      0.176811         0.001471        0.000112
# 29       1.503821      0.493717         0.001441        0.000093
# 30       1.885608      0.873921         0.001433        0.000071
# 31       1.741200      0.525050         0.001412        0.000102
# 32       1.443266      0.199774         0.001379        0.000020
# 33       1.392392      0.346451         0.001416        0.000106
# 34       1.370401      0.113448         0.001422        0.000121
# 35       1.255313      0.239195         0.001406        0.000122
#
#    param_criterion param_max_depth param_n_estimators  \
# 0     friedman_mse               3                100
# 1     friedman_mse               3                200
# 2     friedman_mse               3                500
# 3     friedman_mse               3               1000
# 4     friedman_mse               5                100
# 5     friedman_mse               5                200
# 6     friedman_mse               5                500
# 7     friedman_mse               5               1000
# 8     friedman_mse               7                100
# 9     friedman_mse               7                200
# 10    friedman_mse               7                500
# 11    friedman_mse               7               1000
# 12             mse               3                100
# 13             mse               3                200
# 14             mse               3                500
# 15             mse               3               1000
# 16             mse               5                100
# 17             mse               5                200
# 18             mse               5                500
# 19             mse               5               1000
# 20             mse               7                100
# 21             mse               7                200
# 22             mse               7                500
# 23             mse               7               1000
# 24             mae               3                100
# 25             mae               3                200
# 26             mae               3                500
# 27             mae               3               1000
# 28             mae               5                100
# 29             mae               5                200
# 30             mae               5                500
# 31             mae               5               1000
# 32             mae               7                100
# 33             mae               7                200
# 34             mae               7                500
# 35             mae               7               1000
#
#                                                params  split0_test_accuracy  \
# 0   {'criterion': 'friedman_mse', 'max_depth': 3, ...              0.956989
# 1   {'criterion': 'friedman_mse', 'max_depth': 3, ...              0.946237
# 2   {'criterion': 'friedman_mse', 'max_depth': 3, ...              0.956989
# 3   {'criterion': 'friedman_mse', 'max_depth': 3, ...              0.946237
# 4   {'criterion': 'friedman_mse', 'max_depth': 5, ...              0.956989
# 5   {'criterion': 'friedman_mse', 'max_depth': 5, ...              0.956989
# 6   {'criterion': 'friedman_mse', 'max_depth': 5, ...              0.956989
# 7   {'criterion': 'friedman_mse', 'max_depth': 5, ...              0.956989
# 8   {'criterion': 'friedman_mse', 'max_depth': 7, ...              0.924731
# 9   {'criterion': 'friedman_mse', 'max_depth': 7, ...              0.935484
# 10  {'criterion': 'friedman_mse', 'max_depth': 7, ...              0.956989
# 11  {'criterion': 'friedman_mse', 'max_depth': 7, ...              0.903226
# 12  {'criterion': 'mse', 'max_depth': 3, 'n_estima...              0.935484
# 13  {'criterion': 'mse', 'max_depth': 3, 'n_estima...              0.956989
# 14  {'criterion': 'mse', 'max_depth': 3, 'n_estima...              0.946237
# 15  {'criterion': 'mse', 'max_depth': 3, 'n_estima...              0.956989
# 16  {'criterion': 'mse', 'max_depth': 5, 'n_estima...              0.913978
# 17  {'criterion': 'mse', 'max_depth': 5, 'n_estima...              0.956989
# 18  {'criterion': 'mse', 'max_depth': 5, 'n_estima...              0.956989
# 19  {'criterion': 'mse', 'max_depth': 5, 'n_estima...              0.956989
# 20  {'criterion': 'mse', 'max_depth': 7, 'n_estima...              0.903226
# 21  {'criterion': 'mse', 'max_depth': 7, 'n_estima...              0.870968
# 22  {'criterion': 'mse', 'max_depth': 7, 'n_estima...              0.892473
# 23  {'criterion': 'mse', 'max_depth': 7, 'n_estima...              0.913978
# 24  {'criterion': 'mae', 'max_depth': 3, 'n_estima...              0.784946
# 25  {'criterion': 'mae', 'max_depth': 3, 'n_estima...              0.838710
# 26  {'criterion': 'mae', 'max_depth': 3, 'n_estima...              0.838710
# 27  {'criterion': 'mae', 'max_depth': 3, 'n_estima...              0.892473
# 28  {'criterion': 'mae', 'max_depth': 5, 'n_estima...              0.903226
# 29  {'criterion': 'mae', 'max_depth': 5, 'n_estima...              0.838710
# 30  {'criterion': 'mae', 'max_depth': 5, 'n_estima...              0.849462
# 31  {'criterion': 'mae', 'max_depth': 5, 'n_estima...              0.892473
# 32  {'criterion': 'mae', 'max_depth': 7, 'n_estima...              0.838710
# 33  {'criterion': 'mae', 'max_depth': 7, 'n_estima...              0.838710
# 34  {'criterion': 'mae', 'max_depth': 7, 'n_estima...              0.817204
# 35  {'criterion': 'mae', 'max_depth': 7, 'n_estima...              0.903226
#
#     split1_test_accuracy  ...  std_test_accuracy  rank_test_accuracy  \
# 0               0.935484  ...           0.040651                   3
# 1               0.946237  ...           0.043916                   4
# 2               0.903226  ...           0.032404                   6
# 3               0.946237  ...           0.030514                   2
# 4               0.946237  ...           0.069145                  14
# 5               0.946237  ...           0.050080                   9
# 6               0.924731  ...           0.059101                  12
# 7               0.924731  ...           0.048129                   8
# 8               0.860215  ...           0.067907                  22
# 9               0.881720  ...           0.050959                  18
# 10              0.870968  ...           0.059158                  19
# 11              0.892473  ...           0.061977                  20
# 12              0.903226  ...           0.024974                   5
# 13              0.935484  ...           0.045513                   7
# 14              0.946237  ...           0.027396                   1
# 15              0.935484  ...           0.047077                  11
# 16              0.924731  ...           0.039550                  15
# 17              0.924731  ...           0.041269                  10
# 18              0.903226  ...           0.052811                  13
# 19              0.913978  ...           0.052799                  16
# 20              0.935484  ...           0.061365                  17
# 21              0.892473  ...           0.047320                  21
# 22              0.849462  ...           0.047356                  24
# 23              0.913978  ...           0.077435                  23
# 24              0.838710  ...           0.068151                  31
# 25              0.838710  ...           0.061909                  32
# 26              0.860215  ...           0.057061                  25
# 27              0.838710  ...           0.053288                  26
# 28              0.849462  ...           0.068808                  28
# 29              0.870968  ...           0.066646                  27
# 30              0.849462  ...           0.063952                  33
# 31              0.849462  ...           0.087965                  30
# 32              0.860215  ...           0.050441                  29
# 33              0.817204  ...           0.047219                  34
# 34              0.795699  ...           0.055397                  36
# 35              0.881720  ...           0.098358                  35
#
#     split0_test_roc_auc  split1_test_roc_auc  split2_test_roc_auc  \
# 0              0.957447             0.935014             0.923913
# 1              0.946809             0.945883             0.923913
# 2              0.957447             0.902405             0.913043
# 3              0.946809             0.945883             0.923913
# 4              0.957447             0.945883             0.913043
# 5              0.957447             0.945883             0.902174
# 6              0.957447             0.924144             0.902174
# 7              0.957447             0.924144             0.923913
# 8              0.925532             0.859621             0.869565
# 9              0.936170             0.880897             0.891304
# 10             0.957447             0.869796             0.869565
# 11             0.904024             0.891998             0.891304
# 12             0.936170             0.902405             0.923913
# 13             0.957447             0.935014             0.902174
# 14             0.946809             0.945883             0.923913
# 15             0.957447             0.935014             0.880435
# 16             0.914662             0.924144             0.902174
# 17             0.957447             0.923913             0.880435
# 18             0.957447             0.902405             0.923913
# 19             0.957447             0.913275             0.869565
# 20             0.904024             0.935245             0.913043
# 21             0.871878             0.891767             0.847826
# 22             0.893386             0.848520             0.847826
# 23             0.914431             0.913043             0.826087
# 24             0.785846             0.837188             0.858696
# 25             0.840194             0.837882             0.815217
# 26             0.839963             0.859852             0.880435
# 27             0.893154             0.837650             0.815217
# 28             0.904024             0.848289             0.782609
# 29             0.839269             0.869565             0.847826
# 30             0.850601             0.848751             0.782609
# 31             0.893386             0.848057             0.847826
# 32             0.840426             0.859389             0.793478
# 33             0.840194             0.816142             0.771739
# 34             0.819149             0.794635             0.760870
# 35             0.904024             0.880666             0.706522
#
#     split3_test_roc_auc  split4_test_roc_auc  mean_test_roc_auc  \
# 0              0.858696             0.858696           0.906753
# 1              0.869565             0.836957           0.904625
# 2              0.869565             0.869565           0.902405
# 3              0.891304             0.869565           0.915495
# 4              0.847826             0.771739           0.887188
# 5              0.858696             0.826087           0.898057
# 6              0.880435             0.782609           0.889362
# 7              0.858696             0.826087           0.898057
# 8              0.771739             0.739130           0.833117
# 9              0.847826             0.782609           0.867761
# 10             0.847826             0.771739           0.863275
# 11             0.826087             0.739130           0.850509
# 12             0.869565             0.880435           0.902498
# 13             0.880435             0.826087           0.900231
# 14             0.880435             0.891304           0.917669
# 15             0.869565             0.826087           0.893710
# 16             0.869565             0.815217           0.885153
# 17             0.880435             0.836957           0.895837
# 18             0.826087             0.826087           0.887188
# 19             0.847826             0.804348           0.878492
# 20             0.826087             0.771739           0.870028
# 21             0.804348             0.760870           0.835338
# 22             0.815217             0.750000           0.830990
# 23             0.804348             0.706522           0.832886
# 24             0.793478             0.663043           0.787650
# 25             0.771739             0.673913           0.787789
# 26             0.771739             0.728261           0.816050
# 27             0.804348             0.728261           0.815726
# 28             0.760870             0.706522           0.800463
# 29             0.750000             0.695652           0.800463
# 30             0.706522             0.706522           0.779001
# 31             0.717391             0.663043           0.793941
# 32             0.771739             0.717391           0.796485
# 33             0.750000             0.706522           0.776920
# 34             0.663043             0.717391           0.751018
# 35             0.663043             0.717391           0.774329
#
#     std_test_roc_auc  rank_test_roc_auc
# 0           0.040699                  3
# 1           0.043959                  4
# 2           0.032557                  6
# 3           0.030560                  2
# 4           0.069178                 14
# 5           0.050121                  8
# 6           0.059136                 12
# 7           0.048177                  8
# 8           0.068077                 22
# 9           0.051098                 18
# 10          0.059275                 19
# 11          0.062050                 20
# 12          0.025155                  5
# 13          0.045555                  7
# 14          0.027443                  1
# 15          0.047118                 11
# 16          0.039534                 15
# 17          0.041293                 10
# 18          0.052883                 13
# 19          0.052842                 16
# 20          0.061402                 17
# 21          0.047289                 21
# 22          0.047523                 24
# 23          0.077335                 23
# 24          0.067920                 32
# 25          0.062021                 31
# 26          0.057107                 25
# 27          0.053396                 26
# 28          0.068882                 28
# 29          0.066417                 27
# 30          0.064049                 33
# 31          0.087995                 30
# 32          0.050527                 29
# 33          0.047433                 34
# 34          0.055698                 36
# 35          0.098339                 35
#
# [36 rows x 24 columns]

# %% [markdown]
# Лучший набор параметров:

# %%
{'criterion': 'friedman_mse', 'max_depth': 3, 'n_estimators':200}
# Дефолтные, кроме количества estimators.
# Out:
# {'criterion': 'friedman_mse', 'max_depth': 3, 'n_estimators': 200}

# %%
model_final = make_pipeline(VectorizerTransformer(), GradientBoostingClassifier(criterion="mse", n_estimators=500, n_iter_no_change=20))
model_final.fit(X, y)
# Out:
# Tokenization: 100%|██████████| 1591/1591 [00:00<00:00, 19013.03it/s]
# Tokenization: 100%|██████████| 1591/1591 [00:00<00:00, 20054.99it/s]
# Inferring vectors: 100%|██████████| 1591/1591 [00:02<00:00, 594.93it/s]
# Pipeline(steps=[('vectorizertransformer', VectorizerTransformer()),
#                 ('gradientboostingclassifier',
#                  GradientBoostingClassifier(criterion='mse', n_estimators=500,
#                                             n_iter_no_change=20))])

# %%
from sklearn.svm import SVC
model_final = make_pipeline(SVC())

print(cross_validate(model_final, vecs_us, y_us, n_jobs=6, scoring=("accuracy", "roc_auc")))
# model_final.fit(X, y)
# Out:
# {'fit_time': array([10.39857578, 10.66596317,  9.84782743,  9.85521483,  9.94393635]), 'score_time': array([3.1359973 , 2.90479326, 2.97952461, 2.94967985, 2.92286539]), 'test_accuracy': array([0.77895574, 0.79697853, 0.80917042, 0.76252319, 0.79135737]), 'test_roc_auc': array([0.85465407, 0.87532995, 0.89729443, 0.86122383, 0.88122365])}

# %%
# from sklearn.svm import Gradi
model_final = make_pipeline(GradientBoostingClassifier(criterion="mse", n_estimators=500, n_iter_no_change=20))

print(cross_validate(model_final, vecs_us, y_us, n_jobs=6, scoring=("accuracy", "roc_auc")))
# Out:
# {'fit_time': array([2.48437405, 1.53911757, 3.34544635, 3.88991356, 1.66111064]), 'score_time': array([0.0044291 , 0.00442195, 0.00508523, 0.00530338, 0.00433159]), 'test_accuracy': array([0.57720588, 0.98897059, 0.98345588, 0.95404412, 0.99448529]), 'test_roc_auc': array([0.57625973, 1.        , 1.        , 1.        , 1.        ])}

# %%
model_final.fit(vecs_us, y_us)
# Out:
# Pipeline(steps=[('gradientboostingclassifier',
#                  GradientBoostingClassifier(criterion='mse', n_estimators=500,
#                                             n_iter_no_change=20))])

# %% [markdown]
# ## 5. Инференс и подготовка сабмита

# %%
import bs4
test = []
with open("test.csv") as tfile:
    sp = bs4.BeautifulSoup(tfile)
    revs = sp.findAll("review")
    for r in revs:
        test.append(r.text)

# pd.read_csv("test.csv")

# %%
test
# Out:
#     Id                                               text  y
# 0    0  Ужасно слабый аккумулятор, это основной минус ...  0
# 1    1  ценанадежность-неубиваемостьдолго держит батар...  1
# 2    2  подробнее в комментариях\nК сожалению, факт по...  0
# 3    3  я любительница громкой музыки. Тише телефона у...  0
# 4    4  Дата выпуска - 2011 г, емкость - 1430 mAh, тех...  1
# ..  ..                                                ... ..
# 95  95  Нет передней камеры, внутренняя память очень м...  0
# 96  96  Звук при прослушивание музыки хороший,не глючи...  1
# 97  97  Очень маленькая память забита вшитыми и соверш...  0
# 98  98  Удобный корпус,стандартное меню нокиа,камера д...  1
# 99  99  ПО, камера, отсутствие выбора приложение, нево...  0
#
# [100 rows x 3 columns]

# %%
test = pd.read_csv("./test_.csv")

# %%
submission = pd.DataFrame({"text": test})

# %%
submission.head()
# Out:
#                                                 text
# 0  Ужасно слабый аккумулятор, это основной минус ...
# 1  ценанадежность-неубиваемостьдолго держит батар...
# 2  подробнее в комментариях\nК сожалению, факт по...
# 3  я любительница громкой музыки. Тише телефона у...
# 4  Дата выпуска - 2011 г, емкость - 1430 mAh, тех...

# %%
submission["label"] = model_final.predict(_vectorizer.transform(submission.text))
# Out:
# Tokenization: 100%|██████████| 100/100 [00:00<00:00, 6965.55it/s]
# Inferring vectors: 100%|██████████| 100/100 [00:00<00:00, 262.00it/s]

# %%
submission["y"] = submission.label.map({1: "pos", 0: "neg"})
submission["y"].value_counts()
# Out:
# pos    82
# neg    18
# Name: y, dtype: int64

# %%
ac

# %%
submission
# Out:
#                                                  text  label    y
# 0   Ужасно слабый аккумулятор, это основной минус ...      1  pos
# 1   ценанадежность-неубиваемостьдолго держит батар...      0  neg
# 2   подробнее в комментариях\nК сожалению, факт по...      1  pos
# 3   я любительница громкой музыки. Тише телефона у...      0  neg
# 4   Дата выпуска - 2011 г, емкость - 1430 mAh, тех...      1  pos
# ..                                                ...    ...  ...
# 95  Нет передней камеры, внутренняя память очень м...      1  pos
# 96  Звук при прослушивание музыки хороший,не глючи...      1  pos
# 97  Очень маленькая память забита вшитыми и соверш...      1  pos
# 98  Удобный корпус,стандартное меню нокиа,камера д...      1  pos
# 99  ПО, камера, отсутствие выбора приложение, нево...      1  pos
#
# [100 rows x 3 columns]

# %%
submission.to_csv("./submission.csv", columns=["y"], index_label="Id")

# %%
submission.to_csv("./test_.csv", index_label="Id", columns=["text"],quoting=csv.QUOTE_NONNUMERIC )

# %%
from csv import

# %%
import csv

# %% [markdown]
# ## 6. Упаковка модели

# %%
import pickle as pkl

# %%
csv.
# Out:
# <module 'csv' from '/home/master/.local/share/miniconda3/lib/python3.8/csv.py'>
